# %% [markdown]
# <a href="https://colab.research.google.com/github/Tar-ive/grants_recsys/blob/master/recommendation_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install psycopg2-binary pandas
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 91.7 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.10

# %%
import psycopg2
import pandas as pd
from google.colab import userdata  # For secrets

# Get Supabase credentials
DB_URL = userdata.get('DATABASE_URL')  # Store in Colab secrets

# Connect
conn = psycopg2.connect(DB_URL)

# %%
# Load grants
grants_df = pd.read_sql("SELECT * FROM grants_data", conn)

# Load researchers
researchers_df = pd.read_sql("SELECT * FROM researchers", conn)
# Out:
# <ipython-input-3-33319607803f>:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   grants_df = pd.read_sql("SELECT * FROM grants_data", conn)
# <ipython-input-3-33319607803f>:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   researchers_df = pd.read_sql("SELECT * FROM researchers", conn)

# %%
researchers_df.isnull().sum()
# Out:
# id                       0
# researcher_id            0
# researcher_name          0
# total_citations          0
# total_works              0
# h_index                  0
# i10_index                0
# concept_1                0
# concept_1_score          0
# concept_2                2
# concept_2_score          2
# years_active             0
# recent_works_count       0
# recent_citations         0
# unique_venues            0
# avg_coauthors            0
# open_access_ratio        0
# top_work_1_id            0
# top_work_1_type          0
# top_work_1_is_oa         0
# top_work_1_keywords      0
# top_work_1_source        0
# top_work_2_id          109
# top_work_2_type        109
# top_work_2_is_oa       109
# top_work_2_keywords    109
# top_work_2_source      109
# top_work_3_id          235
# top_work_3_type        235
# top_work_3_is_oa       235
# top_work_3_keywords    235
# top_work_3_source      235
# top_work_4_id          333
# top_work_4_type        333
# top_work_4_is_oa       333
# top_work_4_keywords    333
# top_work_4_source      333
# top_work_5_id          406
# top_work_5_type        406
# top_work_5_is_oa       406
# top_work_5_keywords    406
# top_work_5_source      406
# top_collaborator_1      14
# top_collaborator_2      64
# top_collaborator_3     132
# top_collaborator_4     210
# top_collaborator_5     285
# dtype: int64

# %%
researchers_df.dtypes
# Out:
# id                       int64
# researcher_id           object
# researcher_name         object
# total_citations          int64
# total_works              int64
# h_index                  int64
# i10_index                int64
# concept_1               object
# concept_1_score        float64
# concept_2               object
# concept_2_score        float64
# years_active             int64
# recent_works_count       int64
# recent_citations         int64
# unique_venues            int64
# avg_coauthors          float64
# open_access_ratio      float64
# top_work_1_id           object
# top_work_1_type         object
# top_work_1_is_oa          bool
# top_work_1_keywords     object
# top_work_1_source       object
# top_work_2_id           object
# top_work_2_type         object
# top_work_2_is_oa        object
# top_work_2_keywords     object
# top_work_2_source       object
# top_work_3_id           object
# top_work_3_type         object
# top_work_3_is_oa        object
# top_work_3_keywords     object
# top_work_3_source       object
# top_work_4_id           object
# top_work_4_type         object
# top_work_4_is_oa        object
# top_work_4_keywords     object
# top_work_4_source       object
# top_work_5_id           object
# top_work_5_type         object
# top_work_5_is_oa        object
# top_work_5_keywords     object
# top_work_5_source       object
# top_collaborator_1      object
# top_collaborator_2      object
# top_collaborator_3      object
# top_collaborator_4      object
# top_collaborator_5      object
# dtype: object

# %%
def clean_researchers(researchers_df):
    # Handle concept missingness (only 2 missing values)
    researchers_df['concept_2'] = researchers_df['concept_2'].fillna(researchers_df['concept_2'].mode()[0])
    researchers_df['concept_2_score'] = researchers_df['concept_2_score'].fillna(researchers_df['concept_2_score'].mean())

    # Handle top works (preserve structure while marking missingness)
    for i in range(2,6):
        prefix = f'top_work_{i}_'
        researchers_df[f'{prefix}id'] = researchers_df[f'{prefix}id'].fillna('')
        researchers_df[f'{prefix}type'] = researchers_df[f'{prefix}type'].fillna('unknown')
        researchers_df[f'{prefix}is_oa'] = researchers_df[f'{prefix}is_oa'].fillna(False)
        researchers_df[f'{prefix}keywords'] = researchers_df[f'{prefix}keywords'].fillna('')
        researchers_df[f'{prefix}source'] = researchers_df[f'{prefix}source'].fillna('unknown')

    # Handle collaborators - encode missingness explicitly
    for i in range(1,6):
        col = f'top_collaborator_{i}'
        researchers_df[col] = researchers_df[col].fillna('No Collaborator')

    return researchers_df

# %%
cleaned_researchers = clean_researchers(researchers_df)
# Out:
# <ipython-input-7-fb036820eca8>:11: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   researchers_df[f'{prefix}is_oa'] = researchers_df[f'{prefix}is_oa'].fillna(False)

# %%
cleaned_researchers.isnull().sum()
# Out:
# id                     0
# researcher_id          0
# researcher_name        0
# total_citations        0
# total_works            0
# h_index                0
# i10_index              0
# concept_1              0
# concept_1_score        0
# concept_2              0
# concept_2_score        0
# years_active           0
# recent_works_count     0
# recent_citations       0
# unique_venues          0
# avg_coauthors          0
# open_access_ratio      0
# top_work_1_id          0
# top_work_1_type        0
# top_work_1_is_oa       0
# top_work_1_keywords    0
# top_work_1_source      0
# top_work_2_id          0
# top_work_2_type        0
# top_work_2_is_oa       0
# top_work_2_keywords    0
# top_work_2_source      0
# top_work_3_id          0
# top_work_3_type        0
# top_work_3_is_oa       0
# top_work_3_keywords    0
# top_work_3_source      0
# top_work_4_id          0
# top_work_4_type        0
# top_work_4_is_oa       0
# top_work_4_keywords    0
# top_work_4_source      0
# top_work_5_id          0
# top_work_5_type        0
# top_work_5_is_oa       0
# top_work_5_keywords    0
# top_work_5_source      0
# top_collaborator_1     0
# top_collaborator_2     0
# top_collaborator_3     0
# top_collaborator_4     0
# top_collaborator_5     0
# dtype: int64

# %%
def normalize_data(researchers_df):
    # Features needing normalization
    numeric_cols = [
        'total_citations', 'total_works', 'h_index',
        'i10_index', 'recent_works_count', 'recent_citations',
        'unique_venues', 'avg_coauthors', 'open_access_ratio'
    ]

    from sklearn.preprocessing import RobustScaler
    scaler = RobustScaler()
    researchers_df[numeric_cols] = scaler.fit_transform(researchers_df[numeric_cols])

    return researchers_df, scaler

# %%
def parameterize_data(researchers_df):
    # 1. Create composite features
    researchers_df['productivity_score'] = researchers_df['recent_works_count'] * researchers_df['avg_coauthors']

    # 2. Temporal decay for citations
    researchers_df['decayed_citations'] = researchers_df['total_citations'] * (0.95 ** researchers_df['years_active'])

    # 3. Combine text features for embeddings
    researchers_df['research_text'] = (
        researchers_df['concept_1'] + " " +
        researchers_df['concept_2'] + " " +
        researchers_df[[f'top_work_{i}_keywords' for i in range(1,6)]]
        .fillna('').agg(' '.join, axis=1)
    )

    return researchers_df

# %%
cleaned_researchers = clean_researchers(researchers_df)
normalized_researchers, scaler = normalize_data(cleaned_researchers)
parameterized_researchers = parameterize_data(normalized_researchers)

# %%
def create_researcher_text(row):
    # Core expertise
    concepts = f"{row['concept_1']} (score: {row['concept_1_score']}) {row['concept_2']} (score: {row['concept_2_score']})"

    # Top works keywords
    works_keywords = " ".join(
        [str(row[f"top_work_{i}_keywords"]) for i in range(1,6)
         if pd.notna(row[f"top_work_{i}_keywords"])] # Move the conditional inside the list comprehension
    )

    # Collaborators
    collaborators = " ".join(
        [str(row[f"top_collaborator_{i}"]) for i in range(1,6)
         if pd.notna(row[f"top_collaborator_{i}"])] # Move the conditional inside the list comprehension
    )

    # Venue diversity
    venues = f"Published in {row['unique_venues']} unique venues"

    return f"{concepts}. Works: {works_keywords}. Collaborators: {collaborators}. {venues}"

researchers_df["research_text"] = researchers_df.apply(create_researcher_text, axis=1)

# %% [markdown]
# # grants data

# %%
import psycopg2
import pandas as pd
from google.colab import userdata  # For secrets

# Get Supabase credentials
DB_URL = userdata.get('DATABASE_URL')  # Store in Colab secrets

# Connect
conn = psycopg2.connect(DB_URL)
grants_df = pd.read_sql("SELECT * FROM grants_data", conn)
# Out:
# <ipython-input-2-fbdadcc23004>:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   grants_df = pd.read_sql("SELECT * FROM grants_data", conn)

# %%
def clean_grants(grants_df):
    # Drop less important columns with high null counts
    grants_df = grants_df.drop(columns=['category_explanation'])

    # Handle critical missing dates - drop rows with missing close_date
    grants_df = grants_df.dropna(subset=['close_date'])

    # Fill categorical missing values
    grants_df['category'] = grants_df['category'].fillna('Other')

    # Handle eligibility_description (critical for embeddings)
    grants_df = grants_df.dropna(subset=['eligibility_description'])

    # Convert dates to datetime
    grants_df['post_date'] = pd.to_datetime(grants_df['post_date'])
    grants_df['close_date'] = pd.to_datetime(grants_df['close_date'])

    return grants_df

cleaned_grants = clean_grants(grants_df.copy())
print(f"Remaining grants: {len(cleaned_grants)}/{len(grants_df)}")
# Out:
# Remaining grants: 3138/5000

# %%
grants_df = cleaned_grants

# %%
grants_df["grant_text"] = grants_df["opportunity_title"] + " " + grants_df["summary_description"] + " " + grants_df["eligibility_description"]

# %%
grants_df.isnull().sum()
# Out:
# opportunity_id             0
# opportunity_number         0
# opportunity_title          0
# opportunity_status         0
# agency                     0
# agency_code                0
# agency_name                0
# category                   0
# award_ceiling              0
# award_floor                0
# estimated_total_funding    0
# expected_awards            0
# post_date                  0
# close_date                 0
# funding_categories         0
# applicant_types            0
# funding_instruments        0
# summary_description        0
# eligibility_description    0
# grant_text                 0
# dtype: int64

# %%
grants_df.isnull().sum()
# Out:
# opportunity_id             0
# opportunity_number         0
# opportunity_title          0
# opportunity_status         0
# agency                     0
# agency_code                0
# agency_name                0
# category                   0
# award_ceiling              0
# award_floor                0
# estimated_total_funding    0
# expected_awards            0
# post_date                  0
# close_date                 0
# funding_categories         0
# applicant_types            0
# funding_instruments        0
# summary_description        0
# eligibility_description    0
# grant_text                 0
# dtype: int64

# %%
# !pip install sentence-transformers[gpu] psycopg2-binary supabase

import torch
import psycopg2
from sqlalchemy import create_engine, text
from sentence_transformers import SentenceTransformer
import numpy as np

# Initialize GPU model
model = SentenceTransformer('all-mpnet-base-v2', device='cuda')
# Out:
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.11/dist-packages (2.9.10)
# Collecting supabase
#   Downloading supabase-2.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sentence-transformers[gpu] in /usr/local/lib/python3.11/dist-packages (3.3.1)
# WARNING: sentence-transformers 3.3.1 does not provide the extra 'gpu'
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[gpu]) (4.47.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[gpu]) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[gpu]) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[gpu]) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[gpu]) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[gpu]) (0.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[gpu]) (11.1.0)
# Collecting gotrue<3.0.0,>=2.11.0 (from supabase)
#   Downloading gotrue-2.11.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: httpx<0.29,>=0.26 in /usr/local/lib/python3.11/dist-packages (from supabase) (0.28.1)
# Collecting postgrest<0.20,>=0.19 (from supabase)
#   Downloading postgrest-0.19.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting realtime<3.0.0,>=2.0.0 (from supabase)
#   Downloading realtime-2.2.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting storage3<0.12,>=0.10 (from supabase)
#   Downloading storage3-0.11.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting supafunc<0.10,>=0.9 (from supabase)
#   Downloading supafunc-0.9.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pydantic<3,>=1.10 in /usr/local/lib/python3.11/dist-packages (from gotrue<3.0.0,>=2.11.0->supabase) (2.10.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.26->supabase) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.26->supabase) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.26->supabase) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.26->supabase) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers[gpu]) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers[gpu]) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers[gpu]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers[gpu]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers[gpu]) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers[gpu]) (4.12.2)
# Collecting deprecation<3.0.0,>=2.1.0 (from postgrest<0.20,>=0.19->supabase)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.11 in /usr/local/lib/python3.11/dist-packages (from realtime<3.0.0,>=2.0.0->supabase) (3.11.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from realtime<3.0.0,>=2.0.0->supabase) (2.8.2)
# Collecting websockets<14,>=11 (from realtime<3.0.0,>=2.0.0->supabase)
#   Downloading websockets-13.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting strenum<0.5.0,>=0.4.15 (from supafunc<0.10,>=0.9->supabase)
#   Downloading StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[gpu]) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers[gpu]) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers[gpu]) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers[gpu]) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers[gpu]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers[gpu]) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers[gpu]) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers[gpu]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers[gpu]) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->realtime<3.0.0,>=2.0.0->supabase) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->realtime<3.0.0,>=2.0.0->supabase) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->realtime<3.0.0,>=2.0.0->supabase) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->realtime<3.0.0,>=2.0.0->supabase) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->realtime<3.0.0,>=2.0.0->supabase) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->realtime<3.0.0,>=2.0.0->supabase) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->realtime<3.0.0,>=2.0.0->supabase) (1.18.3)
# Collecting h2<5,>=3 (from httpx[http2]<0.29,>=0.26->gotrue<3.0.0,>=2.11.0->supabase)
#   Downloading h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10->gotrue<3.0.0,>=2.11.0->supabase) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10->gotrue<3.0.0,>=2.11.0->supabase) (2.27.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.8.1->realtime<3.0.0,>=2.0.0->supabase) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<0.29,>=0.26->supabase) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers[gpu]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers[gpu]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers[gpu]) (2.3.0)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->gotrue<3.0.0,>=2.11.0->supabase)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->gotrue<3.0.0,>=2.11.0->supabase)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Downloading supabase-2.12.0-py3-none-any.whl (16 kB)
# Downloading gotrue-2.11.2-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 4.5 MB/s eta 0:00:00
# Downloading postgrest-0.19.3-py3-none-any.whl (22 kB)
# Downloading realtime-2.2.0-py3-none-any.whl (21 kB)
# Downloading storage3-0.11.1-py3-none-any.whl (17 kB)
# Downloading supafunc-0.9.2-py3-none-any.whl (7.6 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Downloading websockets-13.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 18.5 MB/s eta 0:00:00
# Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.4 MB/s eta 0:00:00
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: strenum, websockets, hyperframe, hpack, deprecation, h2, realtime, supafunc, storage3, postgrest, gotrue, supabase
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.2
#     Uninstalling websockets-14.2:
#       Successfully uninstalled websockets-14.2
# Successfully installed deprecation-2.1.0 gotrue-2.11.2 h2-4.1.0 hpack-4.1.0 hyperframe-6.1.0 postgrest-0.19.3 realtime-2.2.0 storage3-0.11.1 strenum-0.4.15 supabase-2.12.0 supafunc-0.9.2 websockets-13.1
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # researchers embeddings

# %%
DB_URL = userdata.get('DATABASE_URL')
engine = create_engine(DB_URL)

# --- Generate Researcher Embeddings ---
def create_researcher_text(row):
    concepts = f"{row['concept_1']} ({row['concept_1_score']}) {row['concept_2']} ({row['concept_2_score']})"
    works = ' '.join([str(row[f'top_work_{i}_keywords']) for i in range(1,6)])
    collabs = ' '.join([str(row[f'top_collaborator_{i}']) for i in range(1,6)])
    return f"{concepts}. Works: {works}. Collaborators: {collabs}."

with engine.connect() as conn:
    researchers = pd.read_sql("SELECT * FROM researchers", conn)
    researchers['text'] = researchers.apply(create_researcher_text, axis=1)

    # Batch processing with GPU
    researcher_embeddings = model.encode(
        researchers['text'].tolist(),
        batch_size=128,
        device='cuda',
        convert_to_numpy=True
    )

# %%
researchers_df
# Out:
#         id                     researcher_id     researcher_name  \
# 0        1  https://openalex.org/A5046299069      Larry R. Price
# 1        2  https://openalex.org/A5039371296   Michael A. Huston
# 2        3  https://openalex.org/A5070163403       Marcus Felson
# 3        4  https://openalex.org/A5017593645  Togay Ozbakkaloglu
# 4        5  https://openalex.org/A5048215687          Eric Kirby
# ...    ...                               ...                 ...
# 1995  1996  https://openalex.org/A5086995405      Theron Stimmel
# 1996  1997  https://openalex.org/A5036852314  Charles F. Bridges
# 1997  1998  https://openalex.org/A5048816917     Brooke Pfeiffer
# 1998  1999  https://openalex.org/A5091269429         Paula Jones
# 1999  2000  https://openalex.org/A5066108905        Meagan Lewis
#
#       total_citations  total_works    h_index  i10_index           concept_1  \
# 0           64.401231      6.00000   6.714286  11.555556    Computer science
# 1           52.467692      2.40625   5.428571   6.333333             Biology
# 2           52.002462      4.53125   5.000000   7.333333           Sociology
# 3           46.363077     10.31250  10.142857  22.888889   Materials science
# 4           30.225231      8.21875   6.285714   9.333333             Geology
# ...               ...          ...        ...        ...                 ...
# 1995        -0.307692     -0.31250  -0.285714  -0.222222          Psychology
# 1996        -0.307692     -0.34375  -0.428571  -0.222222          Psychology
# 1997        -0.307692     -0.37500  -0.428571  -0.333333          Psychology
# 1998        -0.307692     -0.37500  -0.571429  -0.333333  Economic geography
# 1999        -0.307692     -0.40625  -0.571429  -0.333333          Psychology
#
#       concept_1_score           concept_2  ...  \
# 0                73.1         Mathematics  ...
# 1                93.5             Ecology  ...
# 2                72.7          Psychology  ...
# 3                95.7  Composite material  ...
# 4                92.8             Biology  ...
# ...               ...                 ...  ...
# 1995             66.7    Computer science  ...
# 1996            100.0            Medicine  ...
# 1997             75.0   Political science  ...
# 1998            100.0           Economics  ...
# 1999             66.7            Medicine  ...
#
#                                     top_work_5_keywords  \
# 0     Psychology,Exposure therapy,Virtual reality,Ps...
# 1     Microsite,Facilitation,Competition (biology),C...
# 2     Consumption (sociology),Sociology,Computer sci...
# 3     Materials science,Shrinkage,Flexural strength,...
# 4     Thermochronology,Geology,Denudation,Fission tr...
# ...                                                 ...
# 1995                                   Computer science
# 1996  Psychopathology,Mood,Psychology,Cognition,Perc...
# 1997
# 1998
# 1999
#
#                                   top_work_5_source  \
# 0     Journal of Consulting and Clinical Psychology
# 1                                           Ecology
# 2                     American Behavioral Scientist
# 3                      Journal of Materials Science
# 4                                         Tectonics
# ...                                             ...
# 1995
# 1996
# 1997                                        unknown
# 1998                                        unknown
# 1999                                        unknown
#
#                     top_collaborator_1                top_collaborator_2  \
# 0     https://openalex.org/A5019375929  https://openalex.org/A5009004096
# 1     https://openalex.org/A5024934767  https://openalex.org/A5110483019
# 2     https://openalex.org/A5046958460  https://openalex.org/A5102936013
# 3     https://openalex.org/A5082132566  https://openalex.org/A5043329482
# 4     https://openalex.org/A5038349665  https://openalex.org/A5090086069
# ...                                ...                               ...
# 1995  https://openalex.org/A5084095035  https://openalex.org/A5044359247
# 1996  https://openalex.org/A5015451611  https://openalex.org/A5057970321
# 1997  https://openalex.org/A5112296295  https://openalex.org/A5039882388
# 1998  https://openalex.org/A5110025403  https://openalex.org/A5026433800
# 1999  https://openalex.org/A5013670999  https://openalex.org/A5112778957
#
#                     top_collaborator_3                top_collaborator_4  \
# 0     https://openalex.org/A5101870896  https://openalex.org/A5085670077
# 1     https://openalex.org/A5038398105  https://openalex.org/A5008653559
# 2     https://openalex.org/A5037722191  https://openalex.org/A5109563801
# 3     https://openalex.org/A5040407357  https://openalex.org/A5011064916
# 4     https://openalex.org/A5100685756  https://openalex.org/A5038670501
# ...                                ...                               ...
# 1995  https://openalex.org/A5044085867  https://openalex.org/A5111670397
# 1996                   No Collaborator                   No Collaborator
# 1997  https://openalex.org/A5022399715  https://openalex.org/A5025081768
# 1998  https://openalex.org/A5003097760  https://openalex.org/A5006771536
# 1999  https://openalex.org/A5052556741  https://openalex.org/A5011378152
#
#                     top_collaborator_5 productivity_score decayed_citations  \
# 0     https://openalex.org/A5107483970           2.214036          2.966952
# 1     https://openalex.org/A5103521151           0.000000          6.085320
# 2     https://openalex.org/A5072647442          -1.236093          3.096151
# 3     https://openalex.org/A5019907987          18.327822         15.789485
# 4     https://openalex.org/A5009378840           5.087122          5.284114
# ...                                ...                ...               ...
# 1995  https://openalex.org/A5006419471           0.060203         -0.081083
# 1996                   No Collaborator           0.077483         -0.066043
# 1997  https://openalex.org/A5047735008          -0.054992         -0.250617
# 1998  https://openalex.org/A5091856906           0.074603         -0.053792
# 1999  https://openalex.org/A5008801670           0.050604         -0.046120
#
#                                           research_text
# 0     Computer science (score: 73.1) Mathematics (sc...
# 1     Biology (score: 93.5) Ecology (score: 86.0). W...
# 2     Sociology (score: 72.7) Psychology (score: 65....
# 3     Materials science (score: 95.7) Composite mate...
# 4     Geology (score: 92.8) Biology (score: 87.5). W...
# ...                                                 ...
# 1995  Psychology (score: 66.7) Computer science (sco...
# 1996  Psychology (score: 100.0) Medicine (score: 100...
# 1997  Psychology (score: 75.0) Political science (sc...
# 1998  Economic geography (score: 100.0) Economics (s...
# 1999  Psychology (score: 66.7) Medicine (score: 66.7...
#
# [2000 rows x 50 columns]

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2024.12.14)

# %%
import torch
from sentence_transformers import SentenceTransformer
from huggingface_hub import HfApi, create_repo, notebook_login
import pandas as pd
from sqlalchemy import create_engine, text
import numpy as np
from tqdm import tqdm

# Enable GPU
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
grants_df
# Out:
#      opportunity_id      opportunity_number  \
# 0             15936              07HQPA0028
# 1             15937    ED-GRANTS-070907-001
# 2             15939    ED-GRANTS-070907-002
# 3             15941       NNH07ZEA001N-EDL1
# 4             17675  CNCS-GRANTS-071307-001
# ...             ...                     ...
# 4982          48923       DHS-09-ST-062-001
# 4986          48928             A6310090048
# 4988          48935              PAR-09-245
# 4989          48936             2009-CIP-20
# 4993          48941       BLM-MT-RFA09-1356
#
#                                       opportunity_title opportunity_status  \
# 0     Cooperative Ecosystem Studies Unit, Rocky Moun...           archived
# 1     Youth violence and related issues in persisten...           archived
# 2     State data collection; technical assistance CF...           archived
# 3           ROA 2007: A.6 Entry, Descent, and Landing 1           archived
# 4                                  Volunteer Management           archived
# ...                                                 ...                ...
# 4982  DHS Scientific Leadership Bridge Awards for Mi...           archived
# 4986                       Isle Royale Institue Support           archived
# 4988  Initiative to Maximize Research Education in G...           archived
# 4989  National Academy of Sciences Printed Electroni...           archived
# 4993                          Butte Stewardship Project           archived
#
#          agency agency_code  \
# 0     DOI-USGS1   DOI-USGS1
# 1            ED          ED
# 2            ED          ED
# 3       NASA-HQ     NASA-HQ
# 4          CNCS        CNCS
# ...         ...         ...
# 4982    DHS-OPO     DHS-OPO
# 4986    DOI-NPS     DOI-NPS
# 4988  HHS-NIH11   HHS-NIH11
# 4989   DOC-NIST    DOC-NIST
# 4993        DOI         DOI
#
#                                             agency_name       category  \
# 0                                     Geological Survey  discretionary
# 1                               Department of Education  discretionary
# 2                               Department of Education  discretionary
# 3                                     NASA Headquarters  discretionary
# 4        Corporation for National and Community Service  discretionary
# ...                                                 ...            ...
# 4982  Office of Procurement Operations - Grants Divi...  discretionary
# 4986                              National Park Service  discretionary
# 4988                      National Institutes of Health  discretionary
# 4989     National Institute of Standards and Technology        earmark
# 4993                         Department of the Interior  discretionary
#
#       award_ceiling  award_floor  estimated_total_funding  expected_awards  \
# 0           24957.0      24957.0                  24957.0              1.0
# 1               0.0          0.0                8594000.0             13.0
# 2          400000.0          0.0               13500000.0              0.0
# 3               0.0          0.0                      0.0              0.0
# 4          200000.0      50000.0                 800000.0              6.0
# ...             ...          ...                      ...              ...
# 4982       250000.0          0.0                1000000.0             10.0
# 4986            0.0          0.0                 125000.0              1.0
# 4988        50000.0          0.0                      0.0              0.0
# 4989            0.0          0.0                 475000.0              1.0
# 4993            0.0          0.0                  74000.0              1.0
#
#       post_date close_date                                 funding_categories  \
# 0    2007-07-09 2007-07-19  science_technology_and_other_research_and_deve...
# 1    2007-07-09 2007-08-08                                          education
# 2    2007-07-09 2007-08-23                                          education
# 3    2007-07-09 2007-08-20  science_technology_and_other_research_and_deve...
# 4    2007-07-13 2007-09-06  disaster_prevention_and_relief,regional_develo...
# ...         ...        ...                                                ...
# 4982 2009-08-05 2009-11-02                                          education
# 4986 2009-08-05 2009-08-07                                              other
# 4988 2009-08-06 2012-09-25                                             health
# 4989 2009-08-06 2009-09-06  science_technology_and_other_research_and_deve...
# 4993 2009-08-06 2009-08-31                                  natural_resources
#
#                                         applicant_types  \
# 0                                                 other
# 1                                                 other
# 2                                                 other
# 3                                          unrestricted
# 4     county_governments,nonprofits_non_higher_educa...
# ...                                                 ...
# 4982                                              other
# 4986                                              other
# 4988  other,federally_recognized_native_american_tri...
# 4989                                              other
# 4993                                              other
#
#               funding_instruments  \
# 0           cooperative_agreement
# 1                           grant
# 2                           grant
# 3     cooperative_agreement,grant
# 4                           grant
# ...                           ...
# 4982                        grant
# 4986        cooperative_agreement
# 4988                        grant
# 4989                        grant
# 4993        cooperative_agreement
#
#                                     summary_description  \
# 0     The U.S. Geological Surveys is offering a coo...
# 1     Note:  Each funding opportunity description i...
# 2     Note:  Each funding opportunity description i...
# 3     The National Aeronautics and Space Administrat...
# 4     The Corporation for National and Community Ser...
# ...                                                 ...
# 4982  The Department of Homeland Security (DHS) Scie...
# 4986  Strategic partnership between Isle Royale Nati...
# 4988  Purpose. This funding opportunity supports two...
# 4989  This funding opportunity is not open to compet...
# 4993  Habitat improvement, restoration and enhanceme...
#
#                                 eligibility_description  \
# 0     This financial assistance opportunity is being...
# 1     Eligible Applicants: LEAs in which at least on...
# 2     Note: Eligible entities must submit separate a...
# 3                                          Unrestricted
# 4     The Corporation wants to ensure that all eligi...
# ...                                                 ...
# 4982  Minority Serving Community Colleges - Minority...
# 4986  This is a single source award to Michigan Tech...
# 4988  Other Eligible Applicants include the followin...
# 4989  National Academy of Sciences Printed Electroni...
# 4993  State and local governements, Institutions of ...
#
#                                              grant_text
# 0     Cooperative Ecosystem Studies Unit, Rocky Moun...
# 1     Youth violence and related issues in persisten...
# 2     State data collection; technical assistance CF...
# 3     ROA 2007: A.6 Entry, Descent, and Landing 1 Th...
# 4     Volunteer Management The Corporation for Natio...
# ...                                                 ...
# 4982  DHS Scientific Leadership Bridge Awards for Mi...
# 4986  Isle Royale Institue Support Strategic partner...
# 4988  Initiative to Maximize Research Education in G...
# 4989  National Academy of Sciences Printed Electroni...
# 4993  Butte Stewardship Project Habitat improvement,...
#
# [3138 rows x 20 columns]

# %%
model = SentenceTransformer('all-mpnet-base-v2').to(device)

# Generate grant embeddings
def generate_grant_embeddings(texts, batch_size=256):
    embeddings = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Processing grants"):
        batch = texts[i:i+batch_size]
        with torch.no_grad(), torch.amp.autocast(device_type='cuda', dtype=torch.float16):

            emb = model.encode(batch, convert_to_tensor=True, device=device)
            embeddings.append(emb.cpu().numpy())
    return np.concatenate(embeddings)

grant_texts = grants_df['grant_text'].tolist()
grant_embeddings = generate_grant_embeddings(grant_texts)

# Add to DataFrame
grants_df['embedding'] = [emb.tolist() for emb in grant_embeddings]
# Out:
# Processing grants: 100%|██████████| 13/13 [00:04<00:00,  2.98it/s]

# %%
# Run this in Colab to see grants table columns
with engine.connect() as conn:
    result = conn.execute(text("""
        SELECT column_name
        FROM information_schema.columns
        WHERE table_name = 'grants'
    """))
    print("Grants table columns:", [row[0] for row in result])
# Out:
# Grants table columns: ['portal_id', 'grant_id', 'status', 'last_updated', 'change_notes', 'opportunity_title', 'opportunity_number', 'agency', 'award_amount']

# %%
# If column is "grant_id":
update_db_embeddings('grants', grants_df, 'grant_id')
# Out:
# Updating grants:   0%|          | 0/3138 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'grant_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-44b57d081435> in <cell line: 0>()
#       1 # If column is "grant_id":
# ----> 2 update_db_embeddings('grants', grants_df, 'grant_id')
#
# <ipython-input-28-d1c9f919468e> in update_db_embeddings(table_name, df, id_column)
#       8                     WHERE {id_column} = :id
#       9                 """),
# ---> 10                 {"emb": row['embedding'], "id": row[id_column]}
#      11             )
#      12         conn.commit()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'grant_id'

# %%
# First verify grants_df structure
print("Grants DF columns:", grants_df.columns.tolist())

# If missing grant_id, rename from opportunity_id
if 'opportunity_id' in grants_df.columns and 'grant_id' not in grants_df.columns:
    grants_df = grants_df.rename(columns={'opportunity_id': 'grant_id'})

# Generate embeddings (same as before)
grant_texts = grants_df['opportunity_title'] + " " + grants_df['change_notes']  # Adjust text generation as needed
grant_embeddings = generate_grant_embeddings(grant_texts.tolist())

# Update database
def update_grants():
    with engine.connect() as conn:
        # First add embedding column if missing
        conn.execute(text("""
            ALTER TABLE cleaned_data
            ADD COLUMN IF NOT EXISTS embedding vector(768)
        """))

        # Batch update
        for idx, row in tqdm(grants_df.iterrows(), total=len(grants_df)):
            conn.execute(
                text("""
                    UPDATE cleaned_data
                    SET embedding = :emb
                    WHERE grant_id = :id
                """),
                {"emb": grant_embeddings[idx].tolist(), "id": row['grant_id']}
            )
        conn.commit()

update_grants()
# Out:
# Grants DF columns: ['opportunity_id', 'opportunity_number', 'opportunity_title', 'opportunity_status', 'agency', 'agency_code', 'agency_name', 'category', 'award_ceiling', 'award_floor', 'estimated_total_funding', 'expected_awards', 'post_date', 'close_date', 'funding_categories', 'applicant_types', 'funding_instruments', 'summary_description', 'eligibility_description', 'grant_text', 'embedding']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'change_notes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-2fd86732a813> in <cell line: 0>()
#       7
#       8 # Generate embeddings (same as before)
# ----> 9 grant_texts = grants_df['opportunity_title'] + " " + grants_df['change_notes']  # Adjust text generation as needed
#      10 grant_embeddings = generate_grant_embeddings(grant_texts.tolist())
#      11
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'change_notes'

# %%
grants_df
# Out:
#   portal_id grant_id  status               last_updated      change_notes  \
# 0   PID-001    G-001  active 2025-01-22 22:30:53.364705  Initial creation
# 1   PID-002    G-002  closed 2025-01-22 22:30:53.364750           Updated
#
#   opportunity_title opportunity_number agency  award_amount  \
# 0           Grant 1               OP-1    EPA         50000
# 1           Grant 2               OP-2   NASA         75000
#
#                         full_text  \
# 0  Grant 1 Initial creation 50000
# 1           Grant 2 Updated 75000
#
#                                            embedding
# 0  [0.0012575762812048197, 0.015082490630447865, ...
# 1  [-0.01558194775134325, 0.0303270872682333, -0....

# %%
import os
from huggingface_hub import notebook_login
from google.colab import userdata


# Method 1: Environment variable
HF_TOKEN= userdata.get('HF_TOKEN')


# Method 2: Notebook login (recommended)
notebook_login()  # Will prompt for token
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
grants_df.columns
# Out:
# Index(['opportunity_id', 'opportunity_number', 'opportunity_title',
#        'opportunity_status', 'agency', 'agency_code', 'agency_name',
#        'category', 'award_ceiling', 'award_floor', 'estimated_total_funding',
#        'expected_awards', 'post_date', 'close_date', 'funding_categories',
#        'applicant_types', 'funding_instruments', 'summary_description',
#        'eligibility_description', 'grant_text'],
#       dtype='object')

# %%
import pandas as pd
import torch
from sqlalchemy import create_engine, text
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
from huggingface_hub import HfApi, create_repo
import os

# Initialize configuration
MODEL_REPO = "Tarive/findandfund"
DATABASE_URL = userdata.get('DATABASE_URL')
HF_TOKEN = userdata.get('HF_TOKEN')
engine = create_engine(DATABASE_URL)

# Step 1: Create Cleaned Grants Table
with engine.connect() as conn:
    conn.execute(text("DROP TABLE IF EXISTS cleaned_grants"))
    conn.execute(text("""
        CREATE TABLE cleaned_grants (
            opportunity_id TEXT PRIMARY KEY,
            opportunity_title TEXT,
            agency TEXT,
            agency_name TEXT,
            award_ceiling NUMERIC,
            award_floor NUMERIC,
            estimated_total_funding NUMERIC,
            post_date DATE,
            close_date DATE,
            funding_categories TEXT,
            applicant_types TEXT,
            funding_instruments TEXT,
            summary_description TEXT,
            eligibility_description TEXT,
            embedding vector(768)
        )
    """))
    conn.commit()

# Step 2: Generate Embeddings
model = SentenceTransformer('all-mpnet-base-v2', device='cuda')
grants_df['full_text'] = (
    grants_df['opportunity_title'].fillna('') + " | " +
    grants_df['agency_name'].fillna('') + " | " +
    grants_df['summary_description'].fillna('') + " | " +
    grants_df['eligibility_description'].fillna('')
).str.strip()

batch_size = 128
embeddings = []

for i in tqdm(range(0, len(grants_df), batch_size), desc="Generating embeddings"):
    batch = grants_df['full_text'].iloc[i:i+batch_size].tolist()
    batch_emb = model.encode(
        batch,
        batch_size=batch_size,
        device='cuda',
        show_progress_bar=False
    )
    embeddings.extend(batch_emb.tolist())

# Step 3: Insert Data into Database
with engine.connect() as conn:
    data = []
    for idx, row in tqdm(grants_df.iterrows(), total=len(grants_df), desc="Preparing data"):
        if idx >= len(embeddings):
            print(f"Skipping row {idx} - no embedding generated")
            continue

        data.append({
            "id": row['opportunity_id'],
            "title": row['opportunity_title'],
            "agency": row['agency'],
            "agency_name": row['agency_name'],
            "ceiling": row['award_ceiling'],
            "floor": row['award_floor'],
            "funding": row['estimated_total_funding'],
            "post_date": pd.to_datetime(row['post_date']),
            "close_date": pd.to_datetime(row['close_date']),
            "categories": row['funding_categories'],
            "types": row['applicant_types'],
            "instruments": row['funding_instruments'],
            "summary": row['summary_description'],
            "eligibility": row['eligibility_description'],
            "embedding": [float(x) for x in embeddings[idx]]
        })

    # Batch insert with chunks
    chunk_size = 1000
    for i in range(0, len(data), chunk_size):
        conn.execute(
            text("""
                INSERT INTO cleaned_grants VALUES (
                    :id, :title, :agency, :agency_name, :ceiling, :floor, :funding,
                    :post_date, :close_date, :categories, :types, :instruments,
                    :summary, :eligibility, :embedding
                )
            """),
            data[i:i+chunk_size]
        )
        conn.commit()

print("✅ Grants embeddings stored in database")

# Step 4: Save Model to Hugging Face Hub
api = HfApi(token=HF_TOKEN)
create_repo(
    repo_id=MODEL_REPO,
    repo_type="model",
    exist_ok=True
)

model.save_pretrained("grants-embedding-model")

api.upload_folder(
    repo_id=MODEL_REPO,
    folder_path="grants-embedding-model",
    commit_message="Initial commit with grants embedding model"
)

print("✅ Model uploaded to Hugging Face Hub")
# Out:
# Generating embeddings: 100%|██████████| 25/25 [00:16<00:00,  1.50it/s]
# Preparing data:  74%|███████▍  | 2332/3138 [00:00<00:00, 6901.31it/s]
# Skipping row 3148 - no embedding generated
# Skipping row 3152 - no embedding generated
# Skipping row 3153 - no embedding generated
# Skipping row 3155 - no embedding generated
# Skipping row 3157 - no embedding generated
# Skipping row 3158 - no embedding generated
# Skipping row 3160 - no embedding generated
# Skipping row 3161 - no embedding generated
# Skipping row 3164 - no embedding generated
# Skipping row 3166 - no embedding generated
# Skipping row 3167 - no embedding generated
# Skipping row 3168 - no embedding generated
# Skipping row 3170 - no embedding generated
# Skipping row 3171 - no embedding generated
# Skipping row 3172 - no embedding generated
# Skipping row 3174 - no embedding generated
# Skipping row 3175 - no embedding generated
# Skipping row 3176 - no embedding generated
# Skipping row 3183 - no embedding generated
# Skipping row 3184 - no embedding generated
# Skipping row 3186 - no embedding generated
# Skipping row 3189 - no embedding generated
# Skipping row 3190 - no embedding generated
# Skipping row 3191 - no embedding generated
# Skipping row 3194 - no embedding generated
# Skipping row 3197 - no embedding generated
# Skipping row 3200 - no embedding generated
# Skipping row 3205 - no embedding generated
# Skipping row 3211 - no embedding generated
# Skipping row 3213 - no embedding generated
# Skipping row 3214 - no embedding generated
# Skipping row 3215 - no embedding generated
# Skipping row 3217 - no embedding generated
# Skipping row 3219 - no embedding generated
# Skipping row 3220 - no embedding generated
# Skipping row 3221 - no embedding generated
# Skipping row 3222 - no embedding generated
# Skipping row 3225 - no embedding generated
# Skipping row 3231 - no embedding generated
# Skipping row 3232 - no embedding generated
# Skipping row 3233 - no embedding generated
# Skipping row 3234 - no embedding generated
# Skipping row 3235 - no embedding generated
# Skipping row 3237 - no embedding generated
# Skipping row 3241 - no embedding generated
# Skipping row 3242 - no embedding generated
# Skipping row 3243 - no embedding generated
# Skipping row 3244 - no embedding generated
# Skipping row 3245 - no embedding generated
# Skipping row 3247 - no embedding generated
# Skipping row 3248 - no embedding generated
# Skipping row 3249 - no embedding generated
# Skipping row 3251 - no embedding generated
# Skipping row 3252 - no embedding generated
# Skipping row 3253 - no embedding generated
# Skipping row 3254 - no embedding generated
# Skipping row 3256 - no embedding generated
# Skipping row 3257 - no embedding generated
# Skipping row 3258 - no embedding generated
# Skipping row 3266 - no embedding generated
# Skipping row 3267 - no embedding generated
# Skipping row 3268 - no embedding generated
# Skipping row 3269 - no embedding generated
# Skipping row 3271 - no embedding generated
# Skipping row 3272 - no embedding generated
# Skipping row 3273 - no embedding generated
# Skipping row 3275 - no embedding generated
# Skipping row 3278 - no embedding generated
# Skipping row 3279 - no embedding generated
# Skipping row 3280 - no embedding generated
# Skipping row 3282 - no embedding generated
# Skipping row 3283 - no embedding generated
# Skipping row 3285 - no embedding generated
# Skipping row 3286 - no embedding generated
# Skipping row 3287 - no embedding generated
# Skipping row 3289 - no embedding generated
# Skipping row 3290 - no embedding generated
# Skipping row 3291 - no embedding generated
# Skipping row 3292 - no embedding generated
# Skipping row 3293 - no embedding generated
# Skipping row 3294 - no embedding generated
# Skipping row 3297 - no embedding generated
# Skipping row 3298 - no embedding generated
# Skipping row 3299 - no embedding generated
# Skipping row 3300 - no embedding generated
# Skipping row 3302 - no embedding generated
# Skipping row 3303 - no embedding generated
# Skipping row 3304 - no embedding generated
# Skipping row 3305 - no embedding generated
# Skipping row 3306 - no embedding generated
# Skipping row 3307 - no embedding generated
# Skipping row 3308 - no embedding generated
# Skipping row 3309 - no embedding generated
# Skipping row 3314 - no embedding generated
# Skipping row 3315 - no embedding generated
# Skipping row 3317 - no embedding generated
# Skipping row 3318 - no embedding generated
# Skipping row 3319 - no embedding generated
# Skipping row 3320 - no embedding generated
# Skipping row 3321 - no embedding generated
# Skipping row 3323 - no embedding generated
# Skipping row 3324 - no embedding generated
# Skipping row 3325 - no embedding generated
# Skipping row 3327 - no embedding generated
# Skipping row 3329 - no embedding generated
# Skipping row 3330 - no embedding generated
# Skipping row 3331 - no embedding generated
# Skipping row 3334 - no embedding generated
# Skipping row 3335 - no embedding generated
# Skipping row 3337 - no embedding generated
# Skipping row 3338 - no embedding generated
# Skipping row 3340 - no embedding generated
# Skipping row 3343 - no embedding generated
# Skipping row 3344 - no embedding generated
# Skipping row 3346 - no embedding generated
# Skipping row 3347 - no embedding generated
# Skipping row 3349 - no embedding generated
# Skipping row 3350 - no embedding generated
# Skipping row 3351 - no embedding generated
# Skipping row 3352 - no embedding generated
# Skipping row 3353 - no embedding generated
# Skipping row 3355 - no embedding generated
# Skipping row 3356 - no embedding generated
# Skipping row 3357 - no embedding generated
# Skipping row 3358 - no embedding generated
# Skipping row 3359 - no embedding generated
# Skipping row 3362 - no embedding generated
# Skipping row 3365 - no embedding generated
# Skipping row 3370 - no embedding generated
# Skipping row 3371 - no embedding generated
# Skipping row 3372 - no embedding generated
# Skipping row 3373 - no embedding generated
# Skipping row 3374 - no embedding generated
# Skipping row 3375 - no embedding generated
# Skipping row 3376 - no embedding generated
# Skipping row 3377 - no embedding generated
# Skipping row 3380 - no embedding generated
# Skipping row 3382 - no embedding generated
# Skipping row 3385 - no embedding generated
# Skipping row 3387 - no embedding generated
# Skipping row 3388 - no embedding generated
# Skipping row 3389 - no embedding generated
# Skipping row 3390 - no embedding generated
# Skipping row 3392 - no embedding generated
# Skipping row 3395 - no embedding generated
# Skipping row 3398 - no embedding generated
# Skipping row 3400 - no embedding generated
# Skipping row 3402 - no embedding generated
# Skipping row 3404 - no embedding generated
# Skipping row 3409 - no embedding generated
# Skipping row 3410 - no embedding generated
# Skipping row 3411 - no embedding generated
# Skipping row 3412 - no embedding generated
# Skipping row 3413 - no embedding generated
# Skipping row 3414 - no embedding generated
# Skipping row 3417 - no embedding generated
# Skipping row 3418 - no embedding generated
# Skipping row 3419 - no embedding generated
# Skipping row 3420 - no embedding generated
# Skipping row 3421 - no embedding generated
# Skipping row 3423 - no embedding generated
# Skipping row 3425 - no embedding generated
# Skipping row 3427 - no embedding generated
# Skipping row 3429 - no embedding generated
# Skipping row 3431 - no embedding generated
# Skipping row 3432 - no embedding generated
# Skipping row 3433 - no embedding generated
# Skipping row 3434 - no embedding generated
# Skipping row 3435 - no embedding generated
# Skipping row 3437 - no embedding generated
# Skipping row 3438 - no embedding generated
# Skipping row 3439 - no embedding generated
# Skipping row 3440 - no embedding generated
# Skipping row 3441 - no embedding generated
# Skipping row 3443 - no embedding generated
# Skipping row 3444 - no embedding generated
# Skipping row 3445 - no embedding generated
# Skipping row 3446 - no embedding generated
# Skipping row 3449 - no embedding generated
# Skipping row 3450 - no embedding generated
# Skipping row 3452 - no embedding generated
# Skipping row 3453 - no embedding generated
# Skipping row 3454 - no embedding generated
# Skipping row 3455 - no embedding generated
# Skipping row 3456 - no embedding generated
# Skipping row 3457 - no embedding generated
# Skipping row 3460 - no embedding generated
# Skipping row 3476 - no embedding generated
# Skipping row 3477 - no embedding generated
# Skipping row 3478 - no embedding generated
# Skipping row 3480 - no embedding generated
# Skipping row 3481 - no embedding generated
# Skipping row 3482 - no embedding generated
# Skipping row 3490 - no embedding generated
# Skipping row 3491 - no embedding generated
# Skipping row 3494 - no embedding generated
# Skipping row 3495 - no embedding generated
# Skipping row 3496 - no embedding generated
# Skipping row 3497 - no embedding generated
# Skipping row 3498 - no embedding generated
# Skipping row 3499 - no embedding generated
# Skipping row 3502 - no embedding generated
# Skipping row 3506 - no embedding generated
# Skipping row 3508 - no embedding generated
# Skipping row 3509 - no embedding generated
# Skipping row 3510 - no embedding generated
# Skipping row 3511 - no embedding generated
# Skipping row 3514 - no embedding generated
# Skipping row 3515 - no embedding generated
# Skipping row 3516 - no embedding generated
# Skipping row 3517 - no embedding generated
# Skipping row 3519 - no embedding generated
# Skipping row 3520 - no embedding generated
# Skipping row 3521 - no embedding generated
# Skipping row 3522 - no embedding generated
# Skipping row 3524 - no embedding generated
# Skipping row 3526 - no embedding generated
# Skipping row 3527 - no embedding generated
# Skipping row 3529 - no embedding generated
# Skipping row 3531 - no embedding generated
# Skipping row 3533 - no embedding generated
# Skipping row 3536 - no embedding generated
# Skipping row 3537 - no embedding generated
# Skipping row 3538 - no embedding generated
# Skipping row 3539 - no embedding generated
# Skipping row 3541 - no embedding generated
# Skipping row 3542 - no embedding generated
# Skipping row 3543 - no embedding generated
# Skipping row 3544 - no embedding generated
# Skipping row 3545 - no embedding generated
# Skipping row 3546 - no embedding generated
# Skipping row 3547 - no embedding generated
# Skipping row 3548 - no embedding generated
# Skipping row 3550 - no embedding generated
# Skipping row 3551 - no embedding generated
# Skipping row 3553 - no embedding generated
# Skipping row 3554 - no embedding generated
# Skipping row 3555 - no embedding generated
# Skipping row 3556 - no embedding generated
# Skipping row 3557 - no embedding generated
# Skipping row 3558 - no embedding generated
# Skipping row 3559 - no embedding generated
# Skipping row 3560 - no embedding generated
# Skipping row 3561 - no embedding generated
# Skipping row 3563 - no embedding generated
# Skipping row 3564 - no embedding generated
# Skipping row 3568 - no embedding generated
# Skipping row 3569 - no embedding generated
# Skipping row 3571 - no embedding generated
# Skipping row 3574 - no embedding generated
# Skipping row 3576 - no embedding generated
# Skipping row 3592 - no embedding generated
# Skipping row 3593 - no embedding generated
# Skipping row 3596 - no embedding generated
# Skipping row 3597 - no embedding generated
# Skipping row 3606 - no embedding generated
# Skipping row 3607 - no embedding generated
# Skipping row 3611 - no embedding generated
# Skipping row 3614 - no embedding generated
# Skipping row 3615 - no embedding generated
# Skipping row 3618 - no embedding generated
# Skipping row 3620 - no embedding generated
# Skipping row 3621 - no embedding generated
# Skipping row 3622 - no embedding generated
# Skipping row 3623 - no embedding generated
# Skipping row 3624 - no embedding generated
# Skipping row 3625 - no embedding generated
# Skipping row 3626 - no embedding generated
# Skipping row 3630 - no embedding generated
# Skipping row 3633 - no embedding generated
# Skipping row 3634 - no embedding generated
# Skipping row 3636 - no embedding generated
# Skipping row 3637 - no embedding generated
# Skipping row 3638 - no embedding generated
# Skipping row 3639 - no embedding generated
# Skipping row 3640 - no embedding generated
# Skipping row 3641 - no embedding generated
# Skipping row 3643 - no embedding generated
# Skipping row 3644 - no embedding generated
# Skipping row 3645 - no embedding generated
# Skipping row 3646 - no embedding generated
# Skipping row 3647 - no embedding generated
# Skipping row 3648 - no embedding generated
# Skipping row 3650 - no embedding generated
# Skipping row 3652 - no embedding generated
# Skipping row 3655 - no embedding generated
# Skipping row 3660 - no embedding generated
# Skipping row 3661 - no embedding generated
# Skipping row 3662 - no embedding generated
# Skipping row 3663 - no embedding generated
# Skipping row 3664 - no embedding generated
# Skipping row 3665 - no embedding generated
# Skipping row 3666 - no embedding generated
# Skipping row 3667 - no embedding generated
# Skipping row 3668 - no embedding generated
# Skipping row 3669 - no embedding generated
# Skipping row 3670 - no embedding generated
# Skipping row 3671 - no embedding generated
# Skipping row 3672 - no embedding generated
# Skipping row 3673 - no embedding generated
# Skipping row 3675 - no embedding generated
# Skipping row 3677 - no embedding generated
# Skipping row 3679 - no embedding generated
# Skipping row 3680 - no embedding generated
# Skipping row 3681 - no embedding generated
# Skipping row 3682 - no embedding generated
# Skipping row 3683 - no embedding generated
# Skipping row 3684 - no embedding generated
# Skipping row 3685 - no embedding generated
# Skipping row 3686 - no embedding generated
# Skipping row 3687 - no embedding generated
# Skipping row 3688 - no embedding generated
# Skipping row 3689 - no embedding generated
# Skipping row 3691 - no embedding generated
# Skipping row 3692 - no embedding generated
# Skipping row 3693 - no embedding generated
# Skipping row 3694 - no embedding generated
# Skipping row 3696 - no embedding generated
# Skipping row 3697 - no embedding generated
# Skipping row 3698 - no embedding generated
# Skipping row 3699 - no embedding generated
# Skipping row 3700 - no embedding generated
# Skipping row 3701 - no embedding generated
# Skipping row 3702 - no embedding generated
# Skipping row 3703 - no embedding generated
# Skipping row 3704 - no embedding generated
# Skipping row 3705 - no embedding generated
# Skipping row 3706 - no embedding generated
# Skipping row 3707 - no embedding generated
# Skipping row 3708 - no embedding generated
# Skipping row 3711 - no embedding generated
# Skipping row 3713 - no embedding generated
# Skipping row 3714 - no embedding generated
# Skipping row 3715 - no embedding generated
# Skipping row 3717 - no embedding generated
# Skipping row 3718 - no embedding generated
# Skipping row 3719 - no embedding generated
# Skipping row 3720 - no embedding generated
# Skipping row 3721 - no embedding generated
# Skipping row 3722 - no embedding generated
# Skipping row 3723 - no embedding generated
# Skipping row 3724 - no embedding generated
# Skipping row 3726 - no embedding generated
# Skipping row 3727 - no embedding generated
# Skipping row 3728 - no embedding generated
# Skipping row 3729 - no embedding generated
# Skipping row 3731 - no embedding generated
# Skipping row 3732 - no embedding generated
# Skipping row 3733 - no embedding generated
# Skipping row 3734 - no embedding generated
# Skipping row 3735 - no embedding generated
# Skipping row 3736 - no embedding generated
# Skipping row 3737 - no embedding generated
# Skipping row 3738 - no embedding generated
# Skipping row 3739 - no embedding generated
# Skipping row 3740 - no embedding generated
# Skipping row 3741 - no embedding generated
# Skipping row 3742 - no embedding generated
# Skipping row 3743 - no embedding generated
# Skipping row 3744 - no embedding generated
# Skipping row 3745 - no embedding generated
# Skipping row 3746 - no embedding generated
# Skipping row 3747 - no embedding generated
# Skipping row 3748 - no embedding generated
# Skipping row 3749 - no embedding generated
# Skipping row 3751 - no embedding generated
# Skipping row 3752 - no embedding generated
# Skipping row 3753 - no embedding generated
# Skipping row 3755 - no embedding generated
# Skipping row 3759 - no embedding generated
# Skipping row 3760 - no embedding generated
# Skipping row 3762 - no embedding generated
# Skipping row 3763 - no embedding generated
# Skipping row 3764 - no embedding generated
# Skipping row 3765 - no embedding generated
# Skipping row 3767 - no embedding generated
# Skipping row 3768 - no embedding generated
# Skipping row 3770 - no embedding generated
# Skipping row 3771 - no embedding generated
# Skipping row 3773 - no embedding generated
# Skipping row 3774 - no embedding generated
# Skipping row 3776 - no embedding generated
# Skipping row 3778 - no embedding generated
# Skipping row 3779 - no embedding generated
# Skipping row 3780 - no embedding generated
# Skipping row 3782 - no embedding generated
# Skipping row 3783 - no embedding generated
# Skipping row 3785 - no embedding generated
# Skipping row 3786 - no embedding generated
# Skipping row 3787 - no embedding generated
# Skipping row 3788 - no embedding generated
# Skipping row 3789 - no embedding generated
# Skipping row 3790 - no embedding generated
# Skipping row 3792 - no embedding generated
# Skipping row 3793 - no embedding generated
# Skipping row 3794 - no embedding generated
# Skipping row 3795 - no embedding generated
# Skipping row 3796 - no embedding generated
# Skipping row 3797 - no embedding generated
# Skipping row 3799 - no embedding generated
# Skipping row 3803 - no embedding generated
# Skipping row 3804 - no embedding generated
# Skipping row 3808 - no embedding generated
# Skipping row 3812 - no embedding generated
# Skipping row 3814 - no embedding generated
# Skipping row 3816 - no embedding generated
# Skipping row 3818 - no embedding generated
# Skipping row 3819 - no embedding generated
# Skipping row 3820 - no embedding generated
# Skipping row 3822 - no embedding generated
# Skipping row 3823 - no embedding generated
# Skipping row 3824 - no embedding generated
# Skipping row 3825 - no embedding generated
# Skipping row 3826 - no embedding generated
# Skipping row 3827 - no embedding generated
# Skipping row 3829 - no embedding generated
# Skipping row 3830 - no embedding generated
# Skipping row 3831 - no embedding generated
# Skipping row 3832 - no embedding generated
# Skipping row 3836 - no embedding generated
# Skipping row 3837 - no embedding generated
# Skipping row 3838 - no embedding generated
# Skipping row 3839 - no embedding generated
# Skipping row 3840 - no embedding generated
# Skipping row 3841 - no embedding generated
# Skipping row 3842 - no embedding generated
# Skipping row 3843 - no embedding generated
# Skipping row 3844 - no embedding generated
# Skipping row 3845 - no embedding generated
# Skipping row 3847 - no embedding generated
# Skipping row 3848 - no embedding generated
# Skipping row 3849 - no embedding generated
# Skipping row 3850 - no embedding generated
# Skipping row 3851 - no embedding generated
# Skipping row 3852 - no embedding generated
# Skipping row 3854 - no embedding generated
# Skipping row 3857 - no embedding generated
# Skipping row 3858 - no embedding generated
# Skipping row 3859 - no embedding generated
# Skipping row 3860 - no embedding generated
# Skipping row 3861 - no embedding generated
# Skipping row 3862 - no embedding generated
# Skipping row 3863 - no embedding generated
# Skipping row 3864 - no embedding generated
# Skipping row 3865 - no embedding generated
# Skipping row 3866 - no embedding generated
# Skipping row 3867 - no embedding generated
# Skipping row 3868 - no embedding generated
# Skipping row 3869 - no embedding generated
# Skipping row 3871 - no embedding generated
# Skipping row 3876 - no embedding generated
# Skipping row 3877 - no embedding generated
# Skipping row 3878 - no embedding generated
# Skipping row 3879 - no embedding generated
# Skipping row 3880 - no embedding generated
# Skipping row 3881 - no embedding generated
# Skipping row 3882 - no embedding generated
# Skipping row 3883 - no embedding generated
# Skipping row 3885 - no embedding generated
# Skipping row 3886 - no embedding generated
# Skipping row 3887 - no embedding generated
# Skipping row 3888 - no embedding generated
# Skipping row 3890 - no embedding generated
# Skipping row 3892 - no embedding generated
# Skipping row 3894 - no embedding generated
# Skipping row 3895 - no embedding generated
# Skipping row 3897 - no embedding generated
# Skipping row 3898 - no embedding generated
# Skipping row 3899 - no embedding generated
# Skipping row 3901 - no embedding generated
# Skipping row 3903 - no embedding generated
# Skipping row 3904 - no embedding generated
# Skipping row 3907 - no embedding generated
# Skipping row 3910 - no embedding generated
# Skipping row 3911 - no embedding generated
# Skipping row 3913 - no embedding generated
# Skipping row 3914 - no embedding generated
# Skipping row 3917 - no embedding generated
# Skipping row 3918 - no embedding generated
# Skipping row 3919 - no embedding generated
# Skipping row 3920 - no embedding generated
# Skipping row 3928 - no embedding generated
# Skipping row 3929 - no embedding generated
# Skipping row 3933 - no embedding generated
# Skipping row 3935 - no embedding generated
# Skipping row 3936 - no embedding generated
# Skipping row 3937 - no embedding generated
# Skipping row 3939 - no embedding generated
# Skipping row 3941 - no embedding generated
# Skipping row 3942 - no embedding generated
# Skipping row 3944 - no embedding generated
# Skipping row 3945 - no embedding generated
# Skipping row 3946 - no embedding generated
# Skipping row 3947 - no embedding generated
# Skipping row 3948 - no embedding generated
# Skipping row 3949 - no embedding generated
# Skipping row 3951 - no embedding generated
# Skipping row 3952 - no embedding generated
# Skipping row 3953 - no embedding generated
# Skipping row 3957 - no embedding generated
# Skipping row 3958 - no embedding generated
# Skipping row 3960 - no embedding generated
# Skipping row 3961 - no embedding generated
# Skipping row 3962 - no embedding generated
# Skipping row 3963 - no embedding generated
# Skipping row 3964 - no embedding generated
# Skipping row 3965 - no embedding generated
# Skipping row 3966 - no embedding generated
# Skipping row 3970 - no embedding generated
# Skipping row 3971 - no embedding generated
# Skipping row 3972 - no embedding generated
# Skipping row 3973 - no embedding generated
# Skipping row 3974 - no embedding generated
# Skipping row 3975 - no embedding generated
# Skipping row 3980 - no embedding generated
# Skipping row 3981 - no embedding generated
# Skipping row 3982 - no embedding generated
# Skipping row 3983 - no embedding generated
# Skipping row 3984 - no embedding generated
# Skipping row 3985 - no embedding generated
# Skipping row 3986 - no embedding generated
# Skipping row 3987 - no embedding generated
# Skipping row 3988 - no embedding generated
# Skipping row 3989 - no embedding generated
# Skipping row 3990 - no embedding generated
# Skipping row 3991 - no embedding generated
# Skipping row 3992 - no embedding generated
# Skipping row 3993 - no embedding generated
# Skipping row 3994 - no embedding generated
# Skipping row 3996 - no embedding generated
# Skipping row 3997 - no embedding generated
# Skipping row 3998 - no embedding generated
# Skipping row 4000 - no embedding generated
# Skipping row 4004 - no embedding generated
# Skipping row 4008 - no embedding generated
# Skipping row 4011 - no embedding generated
# Skipping row 4012 - no embedding generated
# Skipping row 4013 - no embedding generated
# Skipping row 4015 - no embedding generated
# Skipping row 4016 - no embedding generated
# Skipping row 4020 - no embedding generated
# Skipping row 4022 - no embedding generated
# Skipping row 4023 - no embedding generated
# Skipping row 4027 - no embedding generated
# Skipping row 4028 - no embedding generated
# Skipping row 4029 - no embedding generated
# Skipping row 4030 - no embedding generated
# Skipping row 4031 - no embedding generated
# Skipping row 4032 - no embedding generated
# Skipping row 4035 - no embedding generated
# Skipping row 4037 - no embedding generated
# Skipping row 4038 - no embedding generated
# Skipping row 4039 - no embedding generated
# Skipping row 4040 - no embedding generated
# Skipping row 4041 - no embedding generated
# Skipping row 4042 - no embedding generated
# Skipping row 4043 - no embedding generated
# Skipping row 4044 - no embedding generated
# Skipping row 4046 - no embedding generated
# Skipping row 4049 - no embedding generated
# Skipping row 4050 - no embedding generated
# Skipping row 4054 - no embedding generated
# Skipping row 4055 - no embedding generated
# Skipping row 4056 - no embedding generated
# Skipping row 4057 - no embedding generated
# Skipping row 4058 - no embedding generated
# Skipping row 4059 - no embedding generated
# Skipping row 4061 - no embedding generated
# Skipping row 4062 - no embedding generated
# Skipping row 4063 - no embedding generated
# Skipping row 4064 - no embedding generated
# Skipping row 4066 - no embedding generated
# Skipping row 4067 - no embedding generated
# Skipping row 4068 - no embedding generated
# Skipping row 4075 - no embedding generated
# Skipping row 4077 - no embedding generated
# Skipping row 4078 - no embedding generated
# Skipping row 4079 - no embedding generated
# Skipping row 4081 - no embedding generated
# Skipping row 4083 - no embedding generated
# Skipping row 4085 - no embedding generated
# Skipping row 4086 - no embedding generated
# Skipping row 4087 - no embedding generated
# Skipping row 4090 - no embedding generated
# Skipping row 4091 - no embedding generated
# Skipping row 4093 - no embedding generated
# Skipping row 4095 - no embedding generated
# Preparing data: 100%|██████████| 3138/3138 [00:00<00:00, 5067.99it/s]
# Skipping row 4096 - no embedding generated
# Skipping row 4097 - no embedding generated
# Skipping row 4098 - no embedding generated
# Skipping row 4099 - no embedding generated
# Skipping row 4100 - no embedding generated
# Skipping row 4103 - no embedding generated
# Skipping row 4104 - no embedding generated
# Skipping row 4917 - no embedding generated
# Skipping row 4918 - no embedding generated
# Skipping row 4919 - no embedding generated
# Skipping row 4920 - no embedding generated
# Skipping row 4921 - no embedding generated
# Skipping row 4922 - no embedding generated
# Skipping row 4923 - no embedding generated
# Skipping row 4926 - no embedding generated
# Skipping row 4927 - no embedding generated
# Skipping row 4930 - no embedding generated
# Skipping row 4931 - no embedding generated
# Skipping row 4932 - no embedding generated
# Skipping row 4934 - no embedding generated
# Skipping row 4935 - no embedding generated
# Skipping row 4936 - no embedding generated
# Skipping row 4938 - no embedding generated
# Skipping row 4939 - no embedding generated
# Skipping row 4940 - no embedding generated
# Skipping row 4941 - no embedding generated
# Skipping row 4942 - no embedding generated
# Skipping row 4943 - no embedding generated
# Skipping row 4948 - no embedding generated
# Skipping row 4949 - no embedding generated
# Skipping row 4950 - no embedding generated
# Skipping row 4951 - no embedding generated
# Skipping row 4952 - no embedding generated
# Skipping row 4953 - no embedding generated
# Skipping row 4954 - no embedding generated
# Skipping row 4955 - no embedding generated
# Skipping row 4956 - no embedding generated
# Skipping row 4959 - no embedding generated
# Skipping row 4960 - no embedding generated
# Skipping row 4961 - no embedding generated
# Skipping row 4963 - no embedding generated
# Skipping row 4964 - no embedding generated
# Skipping row 4965 - no embedding generated
# Skipping row 4966 - no embedding generated
# Skipping row 4969 - no embedding generated
# Skipping row 4970 - no embedding generated
# Skipping row 4971 - no embedding generated
# Skipping row 4972 - no embedding generated
# Skipping row 4973 - no embedding generated
# Skipping row 4975 - no embedding generated
# Skipping row 4978 - no embedding generated
# Skipping row 4979 - no embedding generated
# Skipping row 4980 - no embedding generated
# Skipping row 4982 - no embedding generated
# Skipping row 4986 - no embedding generated
# Skipping row 4988 - no embedding generated
# Skipping row 4989 - no embedding generated
# Skipping row 4993 - no embedding generated
# ✅ Grants embeddings stored in database
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# ✅ Model uploaded to Hugging Face Hub

# %% [markdown]
# # generating embeddings safely for grants

# %%
# Generate full_text
grants_df['full_text'] = (
    grants_df['opportunity_title'].fillna('') + " | " +
    grants_df['agency_name'].fillna('') + " | " +
    grants_df['summary_description'].fillna('') + " | " +
    grants_df['eligibility_description'].fillna('')
).str.strip()

# Filter empty texts BEFORE generating embeddings
valid_mask = grants_df['full_text'].str.len() > 10  # At least 10 characters
valid_grants = grants_df[valid_mask].copy()
invalid_grants = grants_df[~valid_mask].copy()

print(f"Valid grants: {len(valid_grants)}, Invalid: {len(invalid_grants)}")
# Out:
# Valid grants: 3138, Invalid: 0

# %%
import pandas as pd
import torch
from sqlalchemy import create_engine, text
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
from huggingface_hub import HfApi, create_repo
import os

# Initialize configuration
MODEL_REPO = "Tarive/findandfund"
DATABASE_URL = userdata.get('DATABASE_URL')
HF_TOKEN = userdata.get('HF_TOKEN')
engine = create_engine(DATABASE_URL)

embeddings = []
batch_size = 128

for i in tqdm(range(0, len(valid_grants), batch_size), desc="Generating embeddings"):
    batch = valid_grants['full_text'].iloc[i:i+batch_size].tolist()
    try:
        with torch.no_grad(), torch.amp.autocast(device_type='cuda', dtype=torch.float16):
            batch_emb = model.encode(
                batch,
                batch_size=batch_size,
                device='cuda',
                convert_to_tensor=True
            )
            embeddings.extend(batch_emb.cpu().numpy().tolist())
    except Exception as e:
        print(f"Failed batch {i//batch_size}: {str(e)}")
        embeddings.extend([None] * len(batch))  # Mark failed entries
# Out:
# Generating embeddings: 100%|██████████| 25/25 [00:21<00:00,  1.18it/s]

# %%
# Add embeddings only to valid grants
valid_grants = valid_grants.reset_index(drop=True)
valid_grants['embedding'] = embeddings

# Combine valid/invalid grants (invalid will have NULL embeddings)
final_df = pd.concat([valid_grants, invalid_grants], ignore_index=True)
final_df = final_df.sort_index()  # Preserve original order

# %%
final_df
# Out:
#      opportunity_id      opportunity_number  \
# 0             15936              07HQPA0028
# 1             15937    ED-GRANTS-070907-001
# 2             15939    ED-GRANTS-070907-002
# 3             15941       NNH07ZEA001N-EDL1
# 4             17675  CNCS-GRANTS-071307-001
# ...             ...                     ...
# 3133          48923       DHS-09-ST-062-001
# 3134          48928             A6310090048
# 3135          48935              PAR-09-245
# 3136          48936             2009-CIP-20
# 3137          48941       BLM-MT-RFA09-1356
#
#                                       opportunity_title opportunity_status  \
# 0     Cooperative Ecosystem Studies Unit, Rocky Moun...           archived
# 1     Youth violence and related issues in persisten...           archived
# 2     State data collection; technical assistance CF...           archived
# 3           ROA 2007: A.6 Entry, Descent, and Landing 1           archived
# 4                                  Volunteer Management           archived
# ...                                                 ...                ...
# 3133  DHS Scientific Leadership Bridge Awards for Mi...           archived
# 3134                       Isle Royale Institue Support           archived
# 3135  Initiative to Maximize Research Education in G...           archived
# 3136  National Academy of Sciences Printed Electroni...           archived
# 3137                          Butte Stewardship Project           archived
#
#          agency agency_code  \
# 0     DOI-USGS1   DOI-USGS1
# 1            ED          ED
# 2            ED          ED
# 3       NASA-HQ     NASA-HQ
# 4          CNCS        CNCS
# ...         ...         ...
# 3133    DHS-OPO     DHS-OPO
# 3134    DOI-NPS     DOI-NPS
# 3135  HHS-NIH11   HHS-NIH11
# 3136   DOC-NIST    DOC-NIST
# 3137        DOI         DOI
#
#                                             agency_name       category  \
# 0                                     Geological Survey  discretionary
# 1                               Department of Education  discretionary
# 2                               Department of Education  discretionary
# 3                                     NASA Headquarters  discretionary
# 4        Corporation for National and Community Service  discretionary
# ...                                                 ...            ...
# 3133  Office of Procurement Operations - Grants Divi...  discretionary
# 3134                              National Park Service  discretionary
# 3135                      National Institutes of Health  discretionary
# 3136     National Institute of Standards and Technology        earmark
# 3137                         Department of the Interior  discretionary
#
#       award_ceiling  award_floor  ...  post_date  close_date  \
# 0           24957.0      24957.0  ... 2007-07-09  2007-07-19
# 1               0.0          0.0  ... 2007-07-09  2007-08-08
# 2          400000.0          0.0  ... 2007-07-09  2007-08-23
# 3               0.0          0.0  ... 2007-07-09  2007-08-20
# 4          200000.0      50000.0  ... 2007-07-13  2007-09-06
# ...             ...          ...  ...        ...         ...
# 3133       250000.0          0.0  ... 2009-08-05  2009-11-02
# 3134            0.0          0.0  ... 2009-08-05  2009-08-07
# 3135        50000.0          0.0  ... 2009-08-06  2012-09-25
# 3136            0.0          0.0  ... 2009-08-06  2009-09-06
# 3137            0.0          0.0  ... 2009-08-06  2009-08-31
#
#                                      funding_categories  \
# 0     science_technology_and_other_research_and_deve...
# 1                                             education
# 2                                             education
# 3     science_technology_and_other_research_and_deve...
# 4     disaster_prevention_and_relief,regional_develo...
# ...                                                 ...
# 3133                                          education
# 3134                                              other
# 3135                                             health
# 3136  science_technology_and_other_research_and_deve...
# 3137                                  natural_resources
#
#                                         applicant_types  \
# 0                                                 other
# 1                                                 other
# 2                                                 other
# 3                                          unrestricted
# 4     county_governments,nonprofits_non_higher_educa...
# ...                                                 ...
# 3133                                              other
# 3134                                              other
# 3135  other,federally_recognized_native_american_tri...
# 3136                                              other
# 3137                                              other
#
#               funding_instruments  \
# 0           cooperative_agreement
# 1                           grant
# 2                           grant
# 3     cooperative_agreement,grant
# 4                           grant
# ...                           ...
# 3133                        grant
# 3134        cooperative_agreement
# 3135                        grant
# 3136                        grant
# 3137        cooperative_agreement
#
#                                     summary_description  \
# 0     The U.S. Geological Surveys is offering a coo...
# 1     Note:  Each funding opportunity description i...
# 2     Note:  Each funding opportunity description i...
# 3     The National Aeronautics and Space Administrat...
# 4     The Corporation for National and Community Ser...
# ...                                                 ...
# 3133  The Department of Homeland Security (DHS) Scie...
# 3134  Strategic partnership between Isle Royale Nati...
# 3135  Purpose. This funding opportunity supports two...
# 3136  This funding opportunity is not open to compet...
# 3137  Habitat improvement, restoration and enhanceme...
#
#                                 eligibility_description  \
# 0     This financial assistance opportunity is being...
# 1     Eligible Applicants: LEAs in which at least on...
# 2     Note: Eligible entities must submit separate a...
# 3                                          Unrestricted
# 4     The Corporation wants to ensure that all eligi...
# ...                                                 ...
# 3133  Minority Serving Community Colleges - Minority...
# 3134  This is a single source award to Michigan Tech...
# 3135  Other Eligible Applicants include the followin...
# 3136  National Academy of Sciences Printed Electroni...
# 3137  State and local governements, Institutions of ...
#
#                                              grant_text  \
# 0     Cooperative Ecosystem Studies Unit, Rocky Moun...
# 1     Youth violence and related issues in persisten...
# 2     State data collection; technical assistance CF...
# 3     ROA 2007: A.6 Entry, Descent, and Landing 1 Th...
# 4     Volunteer Management The Corporation for Natio...
# ...                                                 ...
# 3133  DHS Scientific Leadership Bridge Awards for Mi...
# 3134  Isle Royale Institue Support Strategic partner...
# 3135  Initiative to Maximize Research Education in G...
# 3136  National Academy of Sciences Printed Electroni...
# 3137  Butte Stewardship Project Habitat improvement,...
#
#                                               full_text  \
# 0     Cooperative Ecosystem Studies Unit, Rocky Moun...
# 1     Youth violence and related issues in persisten...
# 2     State data collection; technical assistance CF...
# 3     ROA 2007: A.6 Entry, Descent, and Landing 1 | ...
# 4     Volunteer Management | Corporation for Nationa...
# ...                                                 ...
# 3133  DHS Scientific Leadership Bridge Awards for Mi...
# 3134  Isle Royale Institue Support | National Park S...
# 3135  Initiative to Maximize Research Education in G...
# 3136  National Academy of Sciences Printed Electroni...
# 3137  Butte Stewardship Project | Department of the ...
#
#                                               embedding
# 0     [-0.009195965714752674, 0.045355189591646194, ...
# 1     [0.029821811243891716, 0.006594268139451742, 0...
# 2     [-0.019351482391357422, 0.02426753006875515, -...
# 3     [0.036517173051834106, -0.020543977618217468, ...
# 4     [0.03755396232008934, 0.035538941621780396, 0....
# ...                                                 ...
# 3133  [-0.012140106409788132, 0.04871319234371185, 0...
# 3134  [0.007246552035212517, 0.0414390005171299, -0....
# 3135  [-0.008407034911215305, 0.04766222462058067, -...
# 3136  [-0.004488837439566851, -0.109736368060112, -0...
# 3137  [-0.015314496122300625, 0.030405709519982338, ...
#
# [3138 rows x 22 columns]

# %%
# Check for missing required fields
required_fields = [
    'opportunity_id', 'opportunity_title', 'agency', 'agency_name',
    'award_ceiling', 'award_floor', 'estimated_total_funding',
    'post_date', 'close_date', 'funding_categories', 'applicant_types',
    'funding_instruments', 'summary_description', 'eligibility_description'
]

# Filter rows with missing required fields
valid_rows = []
for idx, row in valid_grants.iterrows():
    if all(row[field] is not None for field in required_fields):
        valid_rows.append({
            "id": row['opportunity_id'],
            "title": row['opportunity_title'],
            "agency": row['agency'],
            "agency_name": row['agency_name'],
            "ceiling": row['award_ceiling'],
            "floor": row['award_floor'],
            "funding": row['estimated_total_funding'],
            "post_date": row['post_date'],
            "close_date": row['close_date'],
            "categories": row['funding_categories'],
            "types": row['applicant_types'],
            "instruments": row['funding_instruments'],
            "summary": row['summary_description'],
            "eligibility": row['eligibility_description'],
            "embedding": row['embedding']
        })
    else:
        print(f"Skipping row {idx} - missing required fields")

print(f"Valid rows: {len(valid_rows)}")
# Out:
# Valid rows: 3138

# %%
import pandas as pd
import torch
from sqlalchemy import create_engine, text
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import os

# Configuration
MODEL_REPO = "Tarive/findandfund"
DATABASE_URL = userdata.get('DATABASE_URL')
engine = create_engine(DATABASE_URL)

# Generate embeddings
embeddings = []
batch_size = 128

for i in tqdm(range(0, len(valid_grants), batch_size), desc="Generating embeddings"):
    batch = valid_grants['full_text'].iloc[i:i+batch_size].tolist()
    try:
        with torch.no_grad(), torch.amp.autocast(device_type='cuda', dtype=torch.float16):
            batch_emb = model.encode(
                batch,
                batch_size=batch_size,
                device='cuda',
                convert_to_tensor=True
            )
            embeddings.extend(batch_emb.cpu().numpy().tolist())
    except Exception as e:
        print(f"Failed batch {i//batch_size}: {str(e)}")
        embeddings.extend([None] * len(batch))

# Insert data in smaller chunks
chunk_size = 100  # Reduced from 1000
with engine.connect() as conn:
    for i in tqdm(range(0, len(valid_grants), chunk_size), desc="Inserting data"):
        chunk_data = []
        for j in range(i, min(i + chunk_size, len(valid_grants))):
            if j >= len(embeddings) or embeddings[j] is None:
                continue

            chunk_data.append({
                "id": valid_grants.iloc[j]['opportunity_id'],
                "title": valid_grants.iloc[j]['opportunity_title'],
                "agency": valid_grants.iloc[j]['agency'],
                "agency_name": valid_grants.iloc[j]['agency_name'],
                "ceiling": valid_grants.iloc[j]['award_ceiling'],
                "floor": valid_grants.iloc[j]['award_floor'],
                "funding": valid_grants.iloc[j]['estimated_total_funding'],
                "post_date": pd.to_datetime(valid_grants.iloc[j]['post_date']),
                "close_date": pd.to_datetime(valid_grants.iloc[j]['close_date']),
                "categories": valid_grants.iloc[j]['funding_categories'],
                "types": valid_grants.iloc[j]['applicant_types'],
                "instruments": valid_grants.iloc[j]['funding_instruments'],
                "summary": valid_grants.iloc[j]['summary_description'],
                "eligibility": valid_grants.iloc[j]['eligibility_description'],
                "embedding": [float(x) for x in embeddings[j]]
            })

        if chunk_data:
            try:
                conn.execute(
                    text("""
                        INSERT INTO cleaned_grants AS t (
                            opportunity_id, opportunity_title, agency, agency_name,
                            award_ceiling, award_floor, estimated_total_funding,
                            post_date, close_date, funding_categories, applicant_types,
                            funding_instruments, summary_description, eligibility_description, embedding
                        ) VALUES (
                            :id, :title, :agency, :agency_name, :ceiling, :floor, :funding,
                            :post_date, :close_date, :categories, :types, :instruments,
                            :summary, :eligibility, :embedding
                        )
                        ON CONFLICT (opportunity_id) DO UPDATE SET
                            opportunity_title = EXCLUDED.opportunity_title,
                            agency = EXCLUDED.agency,
                            agency_name = EXCLUDED.agency_name
                        WHERE t.opportunity_id = EXCLUDED.opportunity_id
                    """),
                    chunk_data
                )
                conn.commit()
            except Exception as e:
                print(f"Error in chunk {i//chunk_size}: {str(e)}")
                continue
# Out:
# Generating embeddings: 100%|██████████| 25/25 [00:20<00:00,  1.22it/s]
# Inserting data: 100%|██████████| 32/32 [09:50<00:00, 18.46s/it]

# %% [markdown]
# # Testing Embeddings.

# %%
from sentence_transformers import SentenceTransformer, util

# Load models
models = {
    "all-mpnet-base-v2": SentenceTransformer('all-mpnet-base-v2'),
    "all-MiniLM-L6-v2": SentenceTransformer('all-MiniLM-L6-v2'),
    "multi-qa-mpnet-base-dot-v1": SentenceTransformer('multi-qa-mpnet-base-dot-v1')
}

# Test on sample grants
sample_texts = [
    "Funding for AI research in healthcare",
    "Grants for renewable energy projects",
    "Support for early-stage startups"
]

# Compare embeddings
for model_name, model in models.items():
    print(f"\nTesting {model_name}:")
    embeddings = model.encode(sample_texts)
    similarities = util.cos_sim(embeddings, embeddings)
    print("Similarity matrix:\n", similarities)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/8.71k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Testing all-mpnet-base-v2:
# Similarity matrix:
#  tensor([[1.0000, 0.3193, 0.2633],
#         [0.3193, 1.0000, 0.2865],
#         [0.2633, 0.2865, 1.0000]])
#
# Testing all-MiniLM-L6-v2:
# Similarity matrix:
#  tensor([[1.0000, 0.2580, 0.1581],
#         [0.2580, 1.0000, 0.1243],
#         [0.1581, 0.1243, 1.0000]])
#
# Testing multi-qa-mpnet-base-dot-v1:
# Similarity matrix:
#  tensor([[1.0000, 0.5120, 0.4102],
#         [0.5120, 1.0000, 0.3912],
#         [0.4102, 0.3912, 1.0000]])

# %% [markdown]
# # can be used by combining embeddings with metadata to get better results.

# %%
def hybrid_score(grant, researcher_embedding):
    semantic_sim = cosine_similarity(researcher_embedding, grant['embedding'])
    funding_score = grant['award_ceiling'] / 1_000_000  # Normalize
    deadline_score = 1 / (1 + grant['days_until_deadline'])
    return 0.7 * semantic_sim + 0.2 * funding_score + 0.1 * deadline_score
