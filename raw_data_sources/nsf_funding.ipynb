# %% [markdown]
# <a href="https://colab.research.google.com/github/Tar-ive/grants_recsys/blob/master/raw_data_sources/nsf_funding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #getting NSF funding data from API

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from tqdm.notebook import tqdm

class NSFGrantsAPI:
    def __init__(self):
        self.base_url = "https://api.nsf.gov/services/v1/awards.json"

    def fetch_grants(self, offset=1, rpp=25):
        """
        Fetches grants from NSF API with pagination
        """
        # Get dates for last 2 years
        end_date = datetime.now()
        start_date = end_date - timedelta(days=730)  # ~2 years

        params = {
            'dateStart': start_date.strftime("%m/%d/%Y"),
            'dateEnd': end_date.strftime("%m/%d/%Y"),
            'offset': offset,
            'rpp': rpp,
            'printFields': (
                'id,title,agency,awardeeName,fundsObligatedAmt,'
                'startDate,expDate,abstractText,piFirstName,piLastName,'
                'awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'
            )
        }

        try:
            print(f"Making request with params: {params}")
            response = requests.get(self.base_url, params=params)
            response.raise_for_status()

            data = response.json()

            # Check for error response
            if 'serviceNotification' in data.get('response', {}):
                error_msg = data['response']['serviceNotification'][0]['notificationMessage']
                print(f"API Error: {error_msg}")
                return None

            return data

        except requests.exceptions.RequestException as e:
            print(f"Error fetching data from NSF API: {e}")
            if hasattr(e, 'response') and e.response is not None:
                print(f"Response content: {e.response.content}")
            return None

    def transform_grant_data(self, award):
        """
        Transforms NSF award data to match our schema
        """
        try:
            # Extract PI name
            pi_name = f"{award.get('piFirstName', '')} {award.get('piLastName', '')}".strip()

            return {
                'opportunity_id': award.get('id'),
                'opportunity_title': award.get('title'),
                'agency': 'NSF',
                'agency_name': award.get('agency'),
                'award_amount': float(award.get('fundsObligatedAmt', 0)),
                'post_date': award.get('startDate') or award.get('date'),
                'close_date': award.get('expDate'),
                'summary_description': award.get('abstractText', ''),
                'applicant_types': award.get('awardeeName', ''),
                'estimated_total': float(award.get('estimatedTotalAmt', 0)),
                'pi_name': pi_name,
                'cfda_number': award.get('cfdaNumber'),
                'state': award.get('awardeeStateCode')
            }
        except Exception as e:
            print(f"Error transforming award data: {e}")
            print(f"Problematic award data: {award}")
            return None

    def get_all_grants(self, max_records=5000):
        """
        Fetches all grants up to max_records
        """
        all_grants = []
        offset = 1
        rpp = 25  # Maximum allowed by API

        with tqdm(total=max_records) as pbar:
            while len(all_grants) < max_records:
                print(f"\nFetching grants {offset} to {offset + rpp - 1}...")

                response_data = self.fetch_grants(offset=offset, rpp=rpp)

                if not response_data or 'response' not in response_data:
                    print("No response data received")
                    break

                awards = response_data['response'].get('award', [])
                if not awards:
                    print("No awards in response")
                    break

                # Transform each award
                transformed_awards = []
                for award in awards:
                    transformed = self.transform_grant_data(award)
                    if transformed:
                        transformed_awards.append(transformed)

                all_grants.extend(transformed_awards)

                offset += rpp
                pbar.update(len(transformed_awards))

                # Respect rate limits
                time.sleep(0.5)  # 500ms delay between requests

                if len(awards) < rpp:  # Last page
                    break

        print(f"\nTotal grants fetched: {len(all_grants)}")
        return pd.DataFrame(all_grants)

def fetch_and_process_nsf_grants(max_records=5000):
    """
    Main function to fetch and process NSF grants
    """
    api = NSFGrantsAPI()

    # Fetch grants
    print("Fetching grants from NSF API...")
    grants_df = api.get_all_grants(max_records=max_records)

    if grants_df.empty:
        print("No grants data retrieved")
        return grants_df

    # Drop rows with missing critical values
    cleaned_df = grants_df.dropna(subset=['post_date', 'close_date', 'award_amount', 'summary_description'])

    # Convert dates to datetime
    cleaned_df['post_date'] = pd.to_datetime(cleaned_df['post_date'])
    cleaned_df['close_date'] = pd.to_datetime(cleaned_df['close_date'])

    print("\nCleaning Summary:")
    print(f"Original records: {len(grants_df)}")
    print(f"Cleaned records: {len(cleaned_df)}")
    print("\nColumns with null values:")
    print(cleaned_df.isnull().sum())

    return cleaned_df

# Run the code
if __name__ == "__main__":
    try:
        nsf_grants_df = fetch_and_process_nsf_grants()
        if not nsf_grants_df.empty:
            nsf_grants_df.to_csv('nsf_grants.csv', index=False)
            print("\nSample of fetched data:")
            print(nsf_grants_df.head())
    except Exception as e:
        print(f"Error in main execution: {e}")
# Out:
# Fetching grants from NSF API...
#   0%|          | 0/5000 [00:00<?, ?it/s]
# Fetching grants 1 to 25...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 26 to 50...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 26, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 51 to 75...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 51, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 76 to 100...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 76, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 101 to 125...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 101, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 126 to 150...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 126, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 151 to 175...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 151, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 176 to 200...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 176, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 201 to 225...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 201, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 226 to 250...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 226, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 251 to 275...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 251, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 276 to 300...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 276, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 301 to 325...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 301, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 326 to 350...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 326, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 351 to 375...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 351, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 376 to 400...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 376, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 401 to 425...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 401, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 426 to 450...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 426, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 451 to 475...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 451, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 476 to 500...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 476, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 501 to 525...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 501, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 526 to 550...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 526, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 551 to 575...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 551, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 576 to 600...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 576, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 601 to 625...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 601, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 626 to 650...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 626, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 651 to 675...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 651, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 676 to 700...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 676, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 701 to 725...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 701, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 726 to 750...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 726, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 751 to 775...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 751, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 776 to 800...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 776, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 801 to 825...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 801, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 826 to 850...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 826, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 851 to 875...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 851, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 876 to 900...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 876, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 901 to 925...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 901, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 926 to 950...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 926, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 951 to 975...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 951, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 976 to 1000...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 976, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1001 to 1025...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1001, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1026 to 1050...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1026, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1051 to 1075...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1051, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1076 to 1100...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1076, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1101 to 1125...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1101, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1126 to 1150...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1126, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1151 to 1175...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1151, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1176 to 1200...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1176, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1201 to 1225...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1201, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1226 to 1250...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1226, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1251 to 1275...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1251, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1276 to 1300...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1276, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1301 to 1325...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1301, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1326 to 1350...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1326, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1351 to 1375...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1351, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1376 to 1400...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1376, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1401 to 1425...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1401, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1426 to 1450...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1426, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1451 to 1475...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1451, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1476 to 1500...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1476, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1501 to 1525...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1501, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1526 to 1550...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1526, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1551 to 1575...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1551, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1576 to 1600...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1576, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1601 to 1625...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1601, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1626 to 1650...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1626, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1651 to 1675...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1651, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1676 to 1700...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1676, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1701 to 1725...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1701, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1726 to 1750...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1726, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1751 to 1775...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1751, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1776 to 1800...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1776, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1801 to 1825...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1801, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1826 to 1850...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1826, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1851 to 1875...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1851, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1876 to 1900...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1876, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1901 to 1925...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1901, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1926 to 1950...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1926, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1951 to 1975...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1951, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 1976 to 2000...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 1976, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2001 to 2025...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2001, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2026 to 2050...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2026, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2051 to 2075...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2051, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2076 to 2100...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2076, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2101 to 2125...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2101, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2126 to 2150...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2126, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2151 to 2175...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2151, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2176 to 2200...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2176, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2201 to 2225...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2201, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2226 to 2250...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2226, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2251 to 2275...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2251, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2276 to 2300...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2276, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2301 to 2325...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2301, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2326 to 2350...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2326, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2351 to 2375...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2351, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2376 to 2400...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2376, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2401 to 2425...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2401, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2426 to 2450...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2426, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2451 to 2475...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2451, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2476 to 2500...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2476, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2501 to 2525...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2501, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2526 to 2550...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2526, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2551 to 2575...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2551, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2576 to 2600...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2576, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2601 to 2625...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2601, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2626 to 2650...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2626, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2651 to 2675...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2651, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2676 to 2700...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2676, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2701 to 2725...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2701, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2726 to 2750...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2726, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2751 to 2775...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2751, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2776 to 2800...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2776, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2801 to 2825...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2801, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2826 to 2850...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2826, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2851 to 2875...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2851, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2876 to 2900...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2876, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2901 to 2925...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2901, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2926 to 2950...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2926, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2951 to 2975...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2951, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 2976 to 3000...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 2976, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3001 to 3025...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3001, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3026 to 3050...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3026, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3051 to 3075...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3051, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3076 to 3100...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3076, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3101 to 3125...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3101, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3126 to 3150...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3126, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3151 to 3175...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3151, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3176 to 3200...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3176, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3201 to 3225...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3201, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3226 to 3250...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3226, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3251 to 3275...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3251, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3276 to 3300...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3276, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3301 to 3325...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3301, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3326 to 3350...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3326, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3351 to 3375...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3351, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3376 to 3400...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3376, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3401 to 3425...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3401, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3426 to 3450...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3426, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3451 to 3475...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3451, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3476 to 3500...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3476, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3501 to 3525...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3501, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3526 to 3550...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3526, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3551 to 3575...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3551, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3576 to 3600...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3576, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3601 to 3625...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3601, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3626 to 3650...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3626, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3651 to 3675...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3651, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3676 to 3700...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3676, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3701 to 3725...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3701, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3726 to 3750...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3726, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3751 to 3775...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3751, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3776 to 3800...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3776, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3801 to 3825...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3801, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3826 to 3850...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3826, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3851 to 3875...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3851, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3876 to 3900...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3876, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3901 to 3925...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3901, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3926 to 3950...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3926, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3951 to 3975...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3951, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 3976 to 4000...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 3976, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4001 to 4025...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4001, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4026 to 4050...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4026, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4051 to 4075...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4051, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4076 to 4100...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4076, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4101 to 4125...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4101, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4126 to 4150...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4126, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4151 to 4175...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4151, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4176 to 4200...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4176, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4201 to 4225...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4201, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4226 to 4250...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4226, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4251 to 4275...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4251, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4276 to 4300...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4276, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4301 to 4325...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4301, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4326 to 4350...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4326, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4351 to 4375...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4351, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4376 to 4400...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4376, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4401 to 4425...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4401, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4426 to 4450...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4426, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4451 to 4475...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4451, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4476 to 4500...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4476, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4501 to 4525...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4501, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4526 to 4550...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4526, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4551 to 4575...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4551, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4576 to 4600...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4576, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4601 to 4625...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4601, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4626 to 4650...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4626, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4651 to 4675...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4651, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4676 to 4700...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4676, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4701 to 4725...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4701, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4726 to 4750...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4726, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}
#
# Fetching grants 4751 to 4775...
# Making request with params: {'dateStart': '01/29/2023', 'dateEnd': '01/28/2025', 'offset': 4751, 'rpp': 25, 'printFields': 'id,title,agency,awardeeName,fundsObligatedAmt,startDate,expDate,abstractText,piFirstName,piLastName,awardeeStateCode,cfdaNumber,date,estimatedTotalAmt'}

# %% [markdown]
# #getting keywords, embedding and storing in db.

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
import torch
import psycopg2
from tqdm.notebook import tqdm
import re
from google.colab import userdata  # For secrets

DB_URL = userdata.get('DATABASE_URL')

# Run the upload process
main()

def preprocess_text(text):
    """Preprocesses text for keyword extraction"""
    if pd.isna(text):
        return ""

    text = str(text)
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\d+', ' ', text)
    text = text.lower().strip()
    text = re.sub(r'\s+', ' ', text)

    return text

def extract_keywords(text, model, vectorizer, n_keywords=5):
    """Extracts keywords using BERT embeddings"""
    if not text or pd.isna(text):
        return []

    text = preprocess_text(text)

    try:
        candidates = vectorizer.get_feature_names_out()

        # Using GPU for embeddings
        with torch.cuda.device(0):
            text_embedding = model.encode([text], convert_to_tensor=True)
            candidate_embeddings = model.encode(candidates, convert_to_tensor=True)

        # Move to CPU for numpy operations
        similarities = torch.mm(candidate_embeddings, text_embedding.T).flatten().cpu().numpy()

        top_idx = similarities.argsort()[-n_keywords:][::-1]
        keywords = [candidates[i] for i in top_idx]

        return keywords
    except Exception as e:
        print(f"Error processing text: {e}")
        return []

def generate_embeddings(texts, model, batch_size=32):
    """Generate embeddings for a list of texts"""
    embeddings = []

    for i in tqdm(range(0, len(texts), batch_size), desc="Generating embeddings"):
        batch_texts = texts[i:i + batch_size]
        with torch.cuda.device(0):
            batch_embeddings = model.encode(batch_texts, convert_to_tensor=True)
            embeddings.extend(batch_embeddings.cpu().numpy())

    return np.array(embeddings)

def process_grants_with_embeddings(grants_df, model_name='all-MiniLM-L6-v2', batch_size=32):
    """Process grants data with keywords and embeddings"""
    print("Initializing model...")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    model = SentenceTransformer(model_name)
    model = model.to(device)

    print("\nInitializing vectorizer...")
    vectorizer = CountVectorizer(
        ngram_range=(1, 2),
        stop_words='english',
        max_features=1000
    )

    # Fit vectorizer on all summaries
    all_texts = grants_df['summary_description'].astype(str).tolist()
    vectorizer.fit(all_texts)

    # Generate keywords
    print("\nGenerating keywords...")
    keywords_list = []
    for i in tqdm(range(0, len(grants_df), batch_size), desc="Extracting keywords"):
        batch = grants_df.iloc[i:i + batch_size]
        batch_keywords = [
            extract_keywords(text, model, vectorizer)
            for text in batch['summary_description']
        ]
        keywords_list.extend(batch_keywords)

    grants_df['keywords'] = keywords_list

    # Generate embeddings
    print("\nGenerating embeddings for summaries...")
    summary_embeddings = generate_embeddings(all_texts, model, batch_size)

    print("Generating embeddings for keywords...")
    keyword_texts = [' '.join(keywords) for keywords in keywords_list]
    keyword_embeddings = generate_embeddings(keyword_texts, model, batch_size)

    # Add embeddings to dataframe
    grants_df['summary_embedding'] = list(summary_embeddings)
    grants_df['keyword_embedding'] = list(keyword_embeddings)

    return grants_df, summary_embeddings, keyword_embeddings

def save_to_database(df, summary_embeddings, keyword_embeddings, db_url):
    """Save processed grants to database"""
    print("\nSaving to database...")

    try:
        conn = psycopg2.connect(db_url)
        with conn.cursor() as cur:
            # Create vector extension if it doesn't exist
            cur.execute("CREATE EXTENSION IF NOT EXISTS vector;")

            # Create table if it doesn't exist
            create_table_query = """
            CREATE TABLE IF NOT EXISTS nsf_grants (
                id SERIAL PRIMARY KEY,
                opportunity_id TEXT,
                opportunity_title TEXT,
                agency TEXT,
                agency_name TEXT,
                award_amount NUMERIC,
                post_date DATE,
                close_date DATE,
                summary_description TEXT,
                applicant_types TEXT,
                estimated_total NUMERIC,
                pi_name TEXT,
                cfda_number TEXT,
                state TEXT,
                keywords TEXT[],
                summary_embedding vector(384),
                keyword_embedding vector(384),
                created_at TIMESTAMP WITH TIME ZONE DEFAULT CURRENT_TIMESTAMP
            );
            """
            cur.execute(create_table_query)

            # Create indexes
            cur.execute("CREATE INDEX IF NOT EXISTS idx_nsf_grants_opportunity_id ON nsf_grants(opportunity_id);")
            cur.execute("CREATE INDEX IF NOT EXISTS idx_nsf_grants_post_date ON nsf_grants(post_date);")

            # Insert data
            for i in tqdm(range(len(df)), desc="Inserting records"):
                row = df.iloc[i]

                insert_query = """
                INSERT INTO nsf_grants (
                    opportunity_id, opportunity_title, agency, agency_name,
                    award_amount, post_date, close_date, summary_description,
                    applicant_types, estimated_total, pi_name, cfda_number,
                    state, keywords, summary_embedding, keyword_embedding
                ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                """

                cur.execute(insert_query, (
                    str(row['opportunity_id']),
                    str(row['opportunity_title']),
                    str(row['agency']),
                    str(row['agency_name']),
                    float(row['award_amount']),
                    row['post_date'],
                    row['close_date'],
                    str(row['summary_description']),
                    str(row['applicant_types']),
                    float(row['estimated_total']),
                    str(row['pi_name']),
                    str(row['cfda_number']),
                    str(row['state']),
                    list(row['keywords']),
                    summary_embeddings[i].tolist(),
                    keyword_embeddings[i].tolist()
                ))

                if (i + 1) % 100 == 0:
                    conn.commit()

            conn.commit()
            print("\nData saved successfully!")

    except Exception as e:
        print(f"Error saving to database: {e}")
        if conn:
            conn.rollback()
    finally:
        if conn:
            conn.close()

def process_and_save_nsf_grants(nsf_grants_df, db_url):
    """Main function to process and save NSF grants"""
    try:
        # Process grants with embeddings
        processed_df, summary_embeddings, keyword_embeddings = process_grants_with_embeddings(nsf_grants_df)

        # Save to database
        save_to_database(processed_df, summary_embeddings, keyword_embeddings, db_url)

        print("\nProcess completed successfully!")
        return processed_df

    except Exception as e:
        print(f"Error in processing and saving: {e}")
        return None

# Example usage
if __name__ == "__main__":
    # Assuming nsf_grants_df and DB_URL are already defined
    processed_df = process_and_save_nsf_grants(nsf_grants_df, DB_URL)
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-2-99ce626c93b5> in <cell line: 0>()
#       9 from google.colab import userdata  # For secrets
#      10
# ---> 11 DB_URL = userdata.get('DATABASE_URL')
#      12
#      13 # Run the upload process
#
# /usr/local/lib/python3.11/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# TimeoutException: Requesting secret DATABASE_URL timed out. Secrets can only be fetched when running from the Colab UI.
